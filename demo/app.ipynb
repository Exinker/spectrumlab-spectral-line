# %%
from spectrumlab.lines import Line

from spectrumlab_line_shape.constants import SIGMA, TAU
from spectrumlab_line_shape.shapes.estimator import LineShapeEstimator, LineShapeEstimatorConfig

# %%
estimator = LineShapeEstimator(
    config=LineShapeEstimatorConfig(
        temperature=800,
        buffer='Ne',
        tau=TAU,
        sigma=SIGMA,
    ),
)

shape = estimator.fit(
    line=Line('Zn', 328.23),
    verbose=True,
    show=True,
    save=True,
)
# Out:
# Zn 328.23:
# 	Natural broadening: 0.006 [pm]
# 	Doppler broadening: 0.822 [pm]
# 	Collision broadening: 2.192 [pm]
# 	FWHM of the shape (by formula): 2.4662 [pm].
